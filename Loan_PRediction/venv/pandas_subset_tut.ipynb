# %%
# Importing pandas as alias pd
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('train_loan.csv', nrows=50)

# %%
df.set_index('Loan_ID', inplace=True)

# %%
# Selecting single columns as a Series

# %%
df['Gender']
# Out:
# Loan_ID
# LP001002      Male
# LP001003      Male
# LP001005      Male
# LP001006      Male
# LP001008      Male
# LP001011      Male
# LP001013      Male
# LP001014      Male
# LP001018      Male
# LP001020      Male
# LP001024      Male
# LP001027      Male
# LP001028      Male
# LP001029      Male
# LP001030      Male
# LP001032      Male
# LP001034      Male
# LP001036    Female
# LP001038      Male
# LP001041      Male
# LP001043      Male
# LP001046      Male
# LP001047      Male
# LP001050       NaN
# LP001052      Male
# LP001066      Male
# LP001068      Male
# LP001073      Male
# LP001086      Male
# LP001087    Female
# LP001091      Male
# LP001095      Male
# LP001097      Male
# LP001098      Male
# LP001100      Male
# LP001106      Male
# LP001109      Male
# LP001112    Female
# LP001114      Male
# LP001116      Male
# LP001119      Male
# LP001120      Male
# LP001123      Male
# LP001131      Male
# LP001136      Male
# LP001137    Female
# LP001138      Male
# ...

# %%
# Selecting single column as a DataFrame

# %%
df[['Education']]
# Out:
#              Education
# Loan_ID
# LP001002      Graduate
# LP001003      Graduate
# LP001005      Graduate
# LP001006  Not Graduate
# LP001008      Graduate
# LP001011      Graduate
# LP001013  Not Graduate
# LP001014      Graduate
# LP001018      Graduate
# LP001020      Graduate
# LP001024      Graduate
# LP001027      Graduate
# LP001028      Graduate
# LP001029      Graduate
# LP001030      Graduate
# LP001032      Graduate
# LP001034  Not Graduate
# LP001036      Graduate
# LP001038  Not Graduate
# LP001041      Graduate
# LP001043  Not Graduate
# LP001046      Graduate
# LP001047  Not Graduate
# LP001050  Not Graduate
# LP001052      Graduate
# LP001066      Graduate
# LP001068      Graduate
# LP001073  Not Graduate
# LP001086  Not Graduate
# LP001087      Graduate
# LP001091      Graduate
# LP001095      Graduate
# LP001097      Graduate
# LP001098      Graduate
# LP001100      Graduate
# LP001106      Graduate
# LP001109      Graduate
# LP001112      Graduate
# ...

# %%
# ***Indexing Operator***

# Selecting multiple **columns** with just indexing operators
# COlumn order doesn't matter
# Select multiple columns by passing a list 
# primary function is to select columns names
# We can actually select rows as well but will be introduced later on

# %%
df[['Gender','Education', 'Dependents']]
# Out:
#           Gender     Education Dependents
# Loan_ID
# LP001002    Male      Graduate          0
# LP001003    Male      Graduate          1
# LP001005    Male      Graduate          0
# LP001006    Male  Not Graduate          0
# LP001008    Male      Graduate          0
# LP001011    Male      Graduate          2
# LP001013    Male  Not Graduate          0
# LP001014    Male      Graduate         3+
# LP001018    Male      Graduate          2
# LP001020    Male      Graduate          1
# LP001024    Male      Graduate          2
# LP001027    Male      Graduate          2
# LP001028    Male      Graduate          2
# LP001029    Male      Graduate          0
# LP001030    Male      Graduate          2
# LP001032    Male      Graduate          0
# LP001034    Male  Not Graduate          1
# LP001036  Female      Graduate          0
# LP001038    Male  Not Graduate          0
# LP001041    Male      Graduate          0
# LP001043    Male  Not Graduate          0
# ...

# %%
# .loc

# %%
# Select a single **row** as a Series using .loc

# %%
df.loc['LP001151']
# Out:
# Gender                  Female
# Married                     No
# Dependents                   0
# Education             Graduate
# Self_Employed               No
# ApplicantIncome           4000
# CoapplicantIncome         2275
# LoanAmount                 144
# Loan_Amount_Term           360
# Credit_History               1
# Property_Area        Semiurban
# Loan_Status                  Y
# Name: LP001151, dtype: object

# %%
type(df.loc['LP001151'])
# Out:
# pandas.core.series.Series

# %%
# Select multiple row as a DataFrame

# %%
df.loc[['LP001114','LP001151']]
# Out:
#           Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# Loan_ID
# LP001114    Male      No          0  Graduate            No             4166
# LP001151  Female      No          0  Graduate            No             4000
#
#           CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# Loan_ID
# LP001114               7210       184.0             360.0             1.0
# LP001151               2275       144.0             360.0             1.0
#
#          Property_Area Loan_Status
# Loan_ID
# LP001114         Urban           Y
# LP001151     Semiurban           Y

# %%
# Select range of row using slice notation
# loc includes the last value (inclusive of last value)

# %%
df.loc['LP001114':'LP001151']
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001114    Male      No          0      Graduate            No
# LP001116    Male      No          0  Not Graduate            No
# LP001119    Male      No          0      Graduate            No
# LP001120    Male      No          0      Graduate            No
# LP001123    Male     Yes          0      Graduate            No
# LP001131    Male     Yes          0      Graduate            No
# LP001136    Male     Yes          0  Not Graduate           Yes
# LP001137  Female      No          0      Graduate            No
# LP001138    Male     Yes          1      Graduate            No
# LP001144    Male     Yes          0      Graduate            No
# LP001146  Female     Yes          0      Graduate            No
# LP001151  Female      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# ...

# %%
df.loc[:'LP001131']
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002    Male      No          0      Graduate            No
# LP001003    Male     Yes          1      Graduate            No
# LP001005    Male     Yes          0      Graduate           Yes
# LP001006    Male     Yes          0  Not Graduate            No
# LP001008    Male      No          0      Graduate            No
# LP001011    Male     Yes          2      Graduate           Yes
# LP001013    Male     Yes          0  Not Graduate            No
# LP001014    Male     Yes         3+      Graduate            No
# LP001018    Male     Yes          2      Graduate            No
# LP001020    Male     Yes          1      Graduate            No
# LP001024    Male     Yes          2      Graduate            No
# LP001027    Male     Yes          2      Graduate           NaN
# LP001028    Male     Yes          2      Graduate            No
# ...

# %%
df.loc['LP001131':]
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001131    Male     Yes          0      Graduate            No
# LP001136    Male     Yes          0  Not Graduate           Yes
# LP001137  Female      No          0      Graduate            No
# LP001138    Male     Yes          1      Graduate            No
# LP001144    Male     Yes          0      Graduate            No
# LP001146  Female     Yes          0      Graduate            No
# LP001151  Female      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001131             3941               2336       134.0             360.0
# LP001136             4695                  0        96.0               NaN
# LP001137             3410                  0        88.0               NaN
# LP001138             5649                  0        44.0             360.0
# ...

# %%
categorical_vars = df.select_dtypes(include=['object'])
continious_columns = df.select_dtypes(include=[np.number])

# %%
categorical_vars.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
continious_columns.columns
# Out:
# Index(['LP001002', 'LP001003', 'LP001005', 'LP001006', 'LP001008', 'LP001011',
#        'LP001013', 'LP001014', 'LP001018', 'LP001020', 'LP001024', 'LP001027',
#        'LP001028', 'LP001029', 'LP001030', 'LP001032', 'LP001034', 'LP001036',
#        'LP001038', 'LP001041', 'LP001043', 'LP001046', 'LP001047', 'LP001050',
#        'LP001052', 'LP001066', 'LP001068', 'LP001073', 'LP001086', 'LP001087',
#        'LP001091', 'LP001095', 'LP001097', 'LP001098', 'LP001100', 'LP001106',
#        'LP001109', 'LP001112', 'LP001114', 'LP001116', 'LP001119', 'LP001120',
#        'LP001123', 'LP001131', 'LP001136', 'LP001137', 'LP001138', 'LP001144',
#        'LP001146', 'LP001151'],
#       dtype='object', name='Loan_ID')

# %%
df.loc[['LP001008','LP001018'], categorical_vars.columns]
# Out:
#          Gender Married Dependents Education Self_Employed Property_Area  \
# Loan_ID
# LP001008   Male      No          0  Graduate            No         Urban
# LP001018   Male     Yes          2  Graduate            No         Urban
#
#          Loan_Status
# Loan_ID
# LP001008           Y
# LP001018           Y

# %%
df.loc[:,categorical_vars.columns]
# Out:
#           Gender Married Dependents     Education Self_Employed Property_Area  \
# Loan_ID
# LP001002    Male      No          0      Graduate            No         Urban
# LP001003    Male     Yes          1      Graduate            No         Rural
# LP001005    Male     Yes          0      Graduate           Yes         Urban
# LP001006    Male     Yes          0  Not Graduate            No         Urban
# LP001008    Male      No          0      Graduate            No         Urban
# LP001011    Male     Yes          2      Graduate           Yes         Urban
# LP001013    Male     Yes          0  Not Graduate            No         Urban
# LP001014    Male     Yes         3+      Graduate            No     Semiurban
# LP001018    Male     Yes          2      Graduate            No         Urban
# LP001020    Male     Yes          1      Graduate            No     Semiurban
# LP001024    Male     Yes          2      Graduate            No         Urban
# ...

# %%
s = pd.Series([True,False,True, True,True],index=['LP001002','LP001003','LP001005','LP001006','LP001008'])

# %%
s
# Out:
# LP001002     True
# LP001003    False
# LP001005     True
# LP001006     True
# LP001008     True
# dtype: bool

# %%
df1 = df.head()

# %%
criterion = [True,False,True, True,True]

# %%
df1
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                  0         NaN             360.0
# LP001003             4583               1508       128.0             360.0
# LP001005             3000                  0        66.0             360.0
# LP001006             2583               2358       120.0             360.0
# LP001008             6000                  0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# ...

# %%
df1[s]
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                  0         NaN             360.0
# LP001005             3000                  0        66.0             360.0
# LP001006             2583               2358       120.0             360.0
# LP001008             6000                  0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001005             1.0         Urban           Y
# LP001006             1.0         Urban           Y
# ...

# %%
a = np.array([True,False,True, True,True])

# %%
df1[a]
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                  0         NaN             360.0
# LP001005             3000                  0        66.0             360.0
# LP001006             2583               2358       120.0             360.0
# LP001008             6000                  0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001005             1.0         Urban           Y
# LP001006             1.0         Urban           Y
# ...

# %%
df1['High_Income'] = df['ApplicantIncome'] >= 5000
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                  0         NaN             360.0
# LP001003             4583               1508       128.0             360.0
# LP001005             3000                  0        66.0             360.0
# LP001006             2583               2358       120.0             360.0
# LP001008             6000                  0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status  High_Income
# Loan_ID
# ...

# %%
df['High_Income'].value_counts()
# Out:
# False    40
# True     10
# Name: High_Income, dtype: int64

# %%
criterion = df['ApplicantIncome'] + df['CoapplicantIncome'] > 6000

# %%
df[criterion].shape[0]
# Out:
# 15

# %%
df.shape[0]
# Out:
# 50

# %%
df[df['ApplicantIncome']+ df['CoapplicantIncome'] >= 8000 ]
# Out:
#          Gender Married Dependents Education Self_Employed  ApplicantIncome  \
# Loan_ID
# LP001011   Male     Yes          2  Graduate           Yes             5417
# LP001020   Male     Yes          1  Graduate            No            12841
# LP001028   Male     Yes          2  Graduate            No             3073
# LP001046   Male     Yes          1  Graduate            No             5955
# LP001066   Male     Yes          0  Graduate           Yes             9560
# LP001100   Male      No         3+  Graduate            No            12500
# LP001114   Male      No          0  Graduate            No             4166
#
#           CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# Loan_ID
# LP001011               4196       267.0             360.0             1.0
# LP001020              10968       349.0             360.0             1.0
# LP001028               8106       200.0             360.0             1.0
# ...

# %%
df.drop('High_Income', axis=1, inplace=True)

# %%
df
# Out:
#           Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002    Male      No          0      Graduate            No
# LP001003    Male     Yes          1      Graduate            No
# LP001005    Male     Yes          0      Graduate           Yes
# LP001006    Male     Yes          0  Not Graduate            No
# LP001008    Male      No          0      Graduate            No
# LP001011    Male     Yes          2      Graduate           Yes
# LP001013    Male     Yes          0  Not Graduate            No
# LP001014    Male     Yes         3+      Graduate            No
# LP001018    Male     Yes          2      Graduate            No
# LP001020    Male     Yes          1      Graduate            No
# LP001024    Male     Yes          2      Graduate            No
# LP001027    Male     Yes          2      Graduate           NaN
# LP001028    Male     Yes          2      Graduate            No
# ...

# %%
df[(df['Education'] == 'Not Graduate') & (df['ApplicantIncome'] > 4500 )]
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001038   Male     Yes          0  Not Graduate            No
# LP001043   Male     Yes          0  Not Graduate            No
# LP001136   Male     Yes          0  Not Graduate           Yes
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001038             4887                  0       133.0             360.0
# LP001043             7660                  0       104.0             360.0
# LP001136             4695                  0        96.0               NaN
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001038             1.0         Rural           N
# LP001043             0.0         Urban           N
# LP001136             1.0         Urban           Y
