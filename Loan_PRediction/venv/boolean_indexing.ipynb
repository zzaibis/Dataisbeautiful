# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv('QueryResults.csv')

# %%
df.shape
# Out:
# (9484, 12)

# %%
df.head()
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2374
# 1  5515021  2011-04-01 14:50:44      9       7677
# 2  5558607  2011-04-05 21:13:50      2       7980
# 3  6467832  2011-06-24 12:31:45     13      15812
# 4  7577546  2011-09-28 01:58:38      9       2712
#
#                                                title  answercount  \
# 0                           Rolling median in python            3
# 1       Compute a compounded return series in Python            3
# 2        Sort a pandas DataMatrix in ascending order            2
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 0             4            1.0         yueerhu      125.0  Mike Pennington
# 1             6            7.0  Jason Strimpel     4596.0  Mike Pennington
# ...

# %%
# Using [] notation

# %%
score_10_plus = df['score'] >= 10

# %%
df[df['score'] >= 10].shape[0]/df.shape[0]*100
# Out:
# 14.466469843947701

# %%
df.columns
# Out:
# Index(['id', 'creationdate', 'score', 'viewcount', 'title', 'answercount',
#        'commentcount', 'favoritecount', 'quest_name', 'quest_rep', 'ans_name',
#        'ans_rep'],
#       dtype='object')

# %%
df[(df['ans_name'] == 'HYRY') & (df['score'] >= 5)].shape
# Out:
# (31, 12)

# %%
len(df['ans_name'].unique())
# Out:
# 1131

# %%
df.head()
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2374
# 1  5515021  2011-04-01 14:50:44      9       7677
# 2  5558607  2011-04-05 21:13:50      2       7980
# 3  6467832  2011-06-24 12:31:45     13      15812
# 4  7577546  2011-09-28 01:58:38      9       2712
#
#                                                title  answercount  \
# 0                           Rolling median in python            3
# 1       Compute a compounded return series in Python            3
# 2        Sort a pandas DataMatrix in ascending order            2
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 0             4            1.0         yueerhu      125.0  Mike Pennington
# 1             6            7.0  Jason Strimpel     4596.0  Mike Pennington
# ...

# %%
df[df['score'].between(73,100)].shape
# Out:
# (72, 12)

# %%
df[(df['score']>=73) & (df['score'] <= 100)].shape
# Out:
# (72, 12)

# %%
# Using loc notation

# %%
# df.loc[(df['score']>=73) & (df['score'] <= 100)].shape

# %%
df.loc[df['viewcount']>1400000,['score','viewcount','ans_name','title']].sort_values(by='score', ascending=False)
# Out:
#       score  viewcount ans_name  \
# 182    1316    1874702   eumiro
# 1176   1248    1640273   unutbu
# 398     738    1515112  joaquin
# 172     705    1426523      ely
#
#                                                   title
# 182                          Renaming columns in pandas
# 1176  Select rows from a DataFrame based on values i...
# 398   Adding new column to existing DataFrame in Pyt...
# 172    Selecting multiple columns in a pandas dataframe

# %%
df.head()
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2374
# 1  5515021  2011-04-01 14:50:44      9       7677
# 2  5558607  2011-04-05 21:13:50      2       7980
# 3  6467832  2011-06-24 12:31:45     13      15812
# 4  7577546  2011-09-28 01:58:38      9       2712
#
#                                                title  answercount  \
# 0                           Rolling median in python            3
# 1       Compute a compounded return series in Python            3
# 2        Sort a pandas DataMatrix in ascending order            2
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 0             4            1.0         yueerhu      125.0  Mike Pennington
# 1             6            7.0  Jason Strimpel     4596.0  Mike Pennington
# ...

# %%
df.loc[~(df['score'] > df['answercount'])].head()
# Out:
#          id         creationdate  score  viewcount  \
# 2   5558607  2011-04-05 21:13:50      2       7980
# 9   8270129  2011-11-25 13:55:02      1        909
# 10  8273092  2011-11-25 18:39:02      1       2403
# 11  8451327  2011-12-09 20:27:24      1       3111
# 15  8957175  2012-01-21 22:12:10      1       1229
#
#                                                 title  answercount  \
# 2         Sort a pandas DataMatrix in ascending order            2
# 9                    Pandas Panel for share portfolio            1
# 10                      python: pandas install errors            2
# 11  Python map() function output into Pandas DataF...            1
# 15  DataFrame to Panel indexed by nonunique column...            1
#
#     commentcount  favoritecount      quest_name  quest_rep      ans_name  \
# 2              0            1.0  Jason Strimpel     4596.0  Wes McKinney
# 9              0            NaN      Evan Davey      125.0  Wes McKinney
# ...

# %%
df.pivot_table(index='ans_name', values='score', aggfunc='sum').sort_values(by= 'score', ascending=False)
# Out:
#                     score
# ans_name
# Andy Hayden          8217
# unutbu               4914
# Jeff                 4231
# DSM                  3413
# Wes McKinney         2921
# EdChum               2419
# eumiro               2305
# waitingkuo           1938
# Wouter Overmeire     1925
# joris                1575
# BrenBarn             1501
# ely                  1227
# Dan Allan            1126
# Alex Riley           1101
# behzad.nouri         1097
# root                  981
# Roman Pekar           813
# joaquin               806
# Simeon Visser         756
# HYRY                  749
# Garrett               710
# chrisb                621
# TomAugspurger         575
# alko                  575
# fred                  567
# Chang She             546
# Zelazny7              546
# Viktor Kerkez         545
# Paul H                475
# Boud                  473
# ...                   ...
# isakkarlsson            0
# Jichao                  0
# Guforu                  0
# ...

# %%
# Practice

# %%
stack = pd.read_csv('stackoverflow_qa.csv')

# %%
stack.shape
# Out:
# (56398, 12)

# %%
stack.head()
# Out:
#         id         creationdate  score  viewcount  \
# 0  5486226  2011-03-30 12:26:50      4       2113
# 1  5515021  2011-04-01 14:50:44      8       7015
# 2  5558607  2011-04-05 21:13:50      2       7392
# 3  6467832  2011-06-24 12:31:45      9      13056
# 4  7577546  2011-09-28 01:58:38      9       2488
#
#                                                title  answercount  \
# 0                           Rolling median in python            3
# 1       Compute a compounded return series in Python            3
# 2        Sort a pandas DataMatrix in ascending order            2
# 3  How to get the correlation between two timeser...            1
# 4  Using pandas, how do I subsample a large DataF...            1
#
#    commentcount  favoritecount      quest_name  quest_rep         ans_name  \
# 0             4            1.0         yueerhu      125.0  Mike Pennington
# 1             6            7.0  Jason Strimpel     3301.0  Mike Pennington
# ...

# %%
employee = pd.read_csv('employee.csv')

# %%
df.loc[df['answercount'] == 5]['title'].shape
# Out:
# (148,)

# %%
df[df['answercount'] == 5]['title'].shape
# Out:
# (148,)

# %%
df[['viewcount','title']].sort_values(by='viewcount', ascending = False)
# Out:
#       viewcount                                              title
# 182     1874702                         Renaming columns in pandas
# 1176    1640273  Select rows from a DataFrame based on values i...
# 398     1515112  Adding new column to existing DataFrame in Pyt...
# 172     1426523   Selecting multiple columns in a pandas dataframe
# 997     1362999  How to iterate over rows in a DataFrame in Pan...
# 4477    1281233      Get list from pandas DataFrame column headers
# 582     1221165  Delete column from pandas DataFrame by column ...
# 2027    1086239  How do I get the row count of a Pandas dataframe?
# 846      981080              Change data type of columns in Pandas
# 956      954066               Pandas writing dataframe to CSV file
# 668      822179  Creating an empty Pandas DataFrame, then filli...
# 107      787962                    Add one row to pandas DataFrame
# 583      624603  How to drop rows of Pandas DataFrame whose val...
# ...

# %%
df.loc[df['quest_name'] == df['ans_name']][['viewcount','score']].sort_values(by=['score','viewcount'], ascending = False)
# Out:
#       viewcount  score
# 2829      95268    175
# 4649     188118     85
# 196       43336     71
# 794       41708     61
# 7350      54760     59
# 6545      61494     58
# 1282      38400     52
# 6369      32857     49
# 1542      69767     47
# 1754      37903     44
# 1582      44952     42
# 8404      13553     42
# 8608      24004     40
# 4746      20714     40
# 5448      18723     40
# 5022      74564     39
# 6471      76358     38
# 6062      34386     36
# 399        9308     34
# 2603      11456     27
# 6975       7295     27
# 59        26949     26
# 321       15172     25
# 7150      27584     23
# 1101      26090     23
# 5793      31998     22
# 1023      43578     21
# 3633      43582     18
# 2458      24548     17
# 4364       1496     17
# ...         ...    ...
# 6976        192      0
# 3846        182      0
# 7603        179      0
# 4919        164      0
# 427         158      0
# 6029        152      0
# 3054        135      0
# 3722        135      0
# ...

# %%
df.loc[(df['ans_name'].isnull()) & (df['score'] > 100)].shape
# Out:
# (16, 12)

# %%
df.loc[df['quest_rep'] > df['ans_rep']].shape
# Out:
# (533, 12)

# %%
df.loc[(df['answercount'].between(5,10)) & (df['viewcount'] < 1000)].shape[0] + df.loc[~((df['answercount'].between(5,10)) & (df['viewcount'] < 1000))].shape[0]
# Out:
# 9484

# %%
employee.head()
# Out:
#                 POSITION_TITLE                     DEPARTMENT  BASE_SALARY  \
# 0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department     121862.0
# 1            LIBRARY ASSISTANT                        Library      26125.0
# 2               POLICE OFFICER  Houston Police Department-HPD      45279.0
# 3            ENGINEER/OPERATOR  Houston Fire Department (HFD)      63166.0
# 4                  ELECTRICIAN    General Services Department      56347.0
#
#               RACE EMPLOYMENT_TYPE  GENDER   HIRE_DATE    JOB_DATE
# 0  Hispanic/Latino       Full Time  Female  2006-06-12  2012-10-13
# 1  Hispanic/Latino       Full Time  Female  2000-07-19  2010-09-18
# 2            White       Full Time    Male  2015-02-03  2015-02-03
# 3            White       Full Time    Male  1982-02-08  1991-05-25
# 4            White       Full Time    Male  1989-06-19  1994-10-22

# %%
type(employee['RACE'].value_counts())
# Out:
# pandas.core.series.Series

# %%
employee.loc[(employee['RACE'] =='Black or African American') & (employee['DEPARTMENT'] == 'Houston Fire Department (HFD)')].shape
# Out:
# (69, 8)

# %%
employee.loc[((employee['BASE_SALARY'] > 100000) & (employee['GENDER'] == 'Female')) | ((employee['BASE_SALARY'] < 50000) & (employee['GENDER'] == 'Male'))].head()
# Out:
#                        POSITION_TITLE                      DEPARTMENT  \
# 0         ASSISTANT DIRECTOR (EX LVL)     Municipal Courts Department
# 2                      POLICE OFFICER   Houston Police Department-HPD
# 7                           CARPENTER    Houston Airport System (HAS)
# 9      AIRPORT OPERATIONS COORDINATOR    Houston Airport System (HAS)
# 12  CUSTOMER SERVICE REPRESENTATIVE I  Public Works & Engineering-PWE
#
#     BASE_SALARY                       RACE EMPLOYMENT_TYPE  GENDER  \
# 0      121862.0            Hispanic/Latino       Full Time  Female
# 2       45279.0                      White       Full Time    Male
# 7       42390.0                      White       Full Time    Male
# 9       44616.0                        NaN       Full Time    Male
# 12      30347.0  Black or African American       Full Time    Male
#
#      HIRE_DATE    JOB_DATE
# 0   2006-06-12  2012-10-13
# 2   2015-02-03  2015-02-03
# 7   2013-11-04  2013-11-04
# ...

# %%
employee.loc[(employee['GENDER'] == 'Female') & (employee['BASE_SALARY'] > 60000) & (employee['DEPARTMENT'].isin(['Parks & Recreation', 'Solid Waste Management', 'Fleet Management Department', 'Library']))].shape
# Out:
# (6, 8)

# %%
employee.loc[(employee['GENDER'] == 'Male') & (employee['BASE_SALARY'] > 100000)][['RACE', 'GENDER', 'BASE_SALARY']]
# Out:
#                            RACE GENDER  BASE_SALARY
# 8                         White   Male     107962.0
# 11    Black or African American   Male     180416.0
# 43              Hispanic/Latino   Male     165216.0
# 169                       White   Male     120916.0
# 178                       White   Male     210588.0
# 186                       White   Male     110881.0
# 217      Asian/Pacific Islander   Male     102019.0
# 297                       White   Male     141948.0
# 299   Black or African American   Male     100228.0
# 416                       White   Male     104455.0
# 561                       White   Male     125884.0
# 593   Black or African American   Male     275000.0
# 708   Black or African American   Male     130585.0
# 713                       White   Male     120750.0
# 719      Asian/Pacific Islander   Male     163228.0
# 767                       White   Male     199596.0
# 855   Black or African American   Male     186192.0
# ...

# %%
lower_than_60k = employee.loc[:,'BASE_SALARY']

# %%
employee.loc[lower_than_60k <25000, 'BASE_SALARY']
# Out:
# 454    24960.0
# Name: BASE_SALARY, dtype: float64

# %%
emp = pd.read_csv('employee_sample.csv',index_col='Name' )

# %%
emp.head()
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY
# Name
# Tom         Male  White         Engineering                23  107962
# Niko        Male  Black         Engineering                 1   30347
# Penelope  Female  White         Engineering                12   60258
# Aria      Female  Black         Engineering                 8   43618
# Sofia     Female  Black  Parks & Recreation                23   26125

# %%
df['SCORE'] = 99

# %%
df.drop('SCORE', axis=1)
# Out:
#             id         creationdate  score  viewcount  \
# 0      5486226  2011-03-30 12:26:50      4       2374
# 1      5515021  2011-04-01 14:50:44      9       7677
# 2      5558607  2011-04-05 21:13:50      2       7980
# 3      6467832  2011-06-24 12:31:45     13      15812
# 4      7577546  2011-09-28 01:58:38      9       2712
# 5      7766400  2011-10-14 10:33:54      2       1027
# 6      7776679  2011-10-15 08:21:17     28      30526
# 7      7813132  2011-10-18 20:16:12     11      23622
# 8      7837722  2011-10-20 14:46:14    280     338225
# 9      8270129  2011-11-25 13:55:02      1        909
# 10     8273092  2011-11-25 18:39:02      1       2403
# 11     8451327  2011-12-09 20:27:24      1       3111
# 12     8842114  2012-01-12 20:52:41      8       4521
# 13     8914992  2012-01-18 18:00:16      4       1008
# 14     8916302  2012-01-18 19:41:27     35      23673
# 15     8957175  2012-01-21 22:12:10      1       1229
# ...

# %%
emp['SCORE'] = 99

# %%
emp
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  SCORE
# Name
# Tom         Male  White         Engineering                23  107962     99
# Niko        Male  Black         Engineering                 1   30347     99
# Penelope  Female  White         Engineering                12   60258     99
# Aria      Female  Black         Engineering                 8   43618     99
# Sofia     Female  Black  Parks & Recreation                23   26125     99
# Dean        Male  Black  Parks & Recreation                 3   33592     99
# Zach        Male  White  Parks & Recreation                 4   37565     99

# %%
emp['random'] = list(np.random.randint(1,10, size=7))

# %%
type(np.random.randint(1,10, size=7))
# Out:
# numpy.ndarray

# %%
emp_
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  random
# Name
# Tom         Male  White         Engineering                23  107962       4
# Niko        Male  Black         Engineering                 1   30347       8
# Penelope  Female  White         Engineering                12   60258       7
# Aria      Female  Black         Engineering                 8   43618       1
# Sofia     Female  Black  Parks & Recreation                23   26125       3
# Dean        Male  Black  Parks & Recreation                 3   33592       5
# Zach        Male  White  Parks & Recreation                 4   37565       3

# %%
last_name = pd.Series(['Smith', 'Jones', 'Williams', 'Green', 
                           'Brown', 'Simpson', 'Peters'])

# %%
last_name
# Out:
# 0       Smith
# 1       Jones
# 2    Williams
# 3       Green
# 4       Brown
# 5     Simpson
# 6      Peters
# dtype: object

# %%
emp['LAST'] = last_name

# %%
list(last_name)
# Out:
# ['Smith', 'Jones', 'Williams', 'Green', 'Brown', 'Simpson', 'Peters']

# %%
last = pd.DataFrame(data=list(last_name), index=[emp.index])

# %%
last
# Out:
#                  0
# Name
# Tom          Smith
# Niko         Jones
# Penelope  Williams
# Aria         Green
# Sofia        Brown
# Dean       Simpson
# Zach        Peters

# %%
emp
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY
# Name
# Tom         Male  White         Engineering                23  107962
# Niko        Male  Black         Engineering                 1   30347
# Penelope  Female  White         Engineering                12   60258
# Aria      Female  Black         Engineering                 8   43618
# Sofia     Female  Black  Parks & Recreation                23   26125
# Dean        Male  Black  Parks & Recreation                 3   33592
# Zach        Male  White  Parks & Recreation                 4   37565

# %%
emp['BONUS RATE'] = [.2, .1, 0, .15, .12, .3, .05]

# %%
emp
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  \
# Name
# Tom         Male  White         Engineering                23  107962
# Niko        Male  Black         Engineering                 1   30347
# Penelope  Female  White         Engineering                12   60258
# Aria      Female  Black         Engineering                 8   43618
# Sofia     Female  Black  Parks & Recreation                23   26125
# Dean        Male  Black  Parks & Recreation                 3   33592
# Zach        Male  White  Parks & Recreation                 4   37565
#
#           BONUS RATE
# Name
# Tom             0.20
# Niko            0.10
# Penelope        0.00
# Aria            0.15
# Sofia           0.12
# Dean            0.30
# Zach            0.05

# %%
emp['Bonus'] = emp['BONUS RATE'] * emp['SALARY']

# %%
emp
# Out:
#           GENDER   RACE          DEPARTMENT  YEARS EXPERIENCE  SALARY  \
# Name
# Tom         Male  White         Engineering                23  107962
# Niko        Male  Black         Engineering                 1   30347
# Penelope  Female  White         Engineering                12   60258
# Aria      Female  Black         Engineering                 8   43618
# Sofia     Female  Black  Parks & Recreation                23   26125
# Dean        Male  Black  Parks & Recreation                 3   33592
# Zach        Male  White  Parks & Recreation                 4   37565
#
#           BONUS RATE     Bonus
# Name
# Tom             0.20  21592.40
# Niko            0.10   3034.70
# Penelope        0.00      0.00
# Aria            0.15   6542.70
# Sofia           0.12   3135.00
# Dean            0.30  10077.60
# Zach            0.05   1878.25

# %%
emp.loc[emp['DEPARTMENT'] == 'Engineering', 'Bonus']
# Out:
# Name
# Tom         21592.4
# Niko         3034.7
# Penelope        0.0
# Aria         6542.7
# Name: Bonus, dtype: float64
