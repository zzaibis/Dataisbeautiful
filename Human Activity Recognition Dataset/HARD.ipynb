# %%
import pandas as pd

# %%
import numpy as np
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train['source'] = 'train'
test['source'] = 'test'
HARD = pd.concat([train, test], sort=False,ignore_index=True )

# %%
HARD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10299 entries, 0 to 10298
# Columns: 564 entries, tBodyAcc-mean()-X to source
# dtypes: float64(561), int64(1), object(2)
# memory usage: 44.3+ MB

# %%
# HARD.isnull().sum()

# %%
# Group and count main names of columns
pd.DataFrame.from_dict(Counter([col.split('-')[0].split('(')[0] for col in HARD.columns]), orient='index').rename(columns={0:'count'}).sort_values('count', ascending=False)
# Out:
#                       count
# fBodyAcc                 79
# fBodyGyro                79
# fBodyAccJerk             79
# tGravityAcc              40
# tBodyAcc                 40
# tBodyGyroJerk            40
# tBodyGyro                40
# tBodyAccJerk             40
# tBodyAccMag              13
# tGravityAccMag           13
# tBodyAccJerkMag          13
# tBodyGyroMag             13
# tBodyGyroJerkMag         13
# fBodyAccMag              13
# fBodyBodyAccJerkMag      13
# fBodyBodyGyroMag         13
# fBodyBodyGyroJerkMag     13
# angle                     7
# subject                   1
# Activity                  1
# source                    1

# %%
HARD.isna().sum().sum()
HARD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10299 entries, 0 to 10298
# Columns: 564 entries, tBodyAcc-mean()-X to source
# dtypes: float64(561), int64(1), object(2)
# memory usage: 44.3+ MB

# %%
HARD.describe()
# Out:
#        tBodyAcc-mean()-X  tBodyAcc-mean()-Y  tBodyAcc-mean()-Z  \
# count       10299.000000       10299.000000       10299.000000
# mean            0.274347          -0.017743          -0.108925
# std             0.067628           0.037128           0.053033
# min            -1.000000          -1.000000          -1.000000
# 25%             0.262625          -0.024902          -0.121019
# 50%             0.277174          -0.017162          -0.108596
# 75%             0.288354          -0.010625          -0.097589
# max             1.000000           1.000000           1.000000
#
#        tBodyAcc-std()-X  tBodyAcc-std()-Y  tBodyAcc-std()-Z  tBodyAcc-mad()-X  \
# count      10299.000000      10299.000000      10299.000000      10299.000000
# mean          -0.607784         -0.510191         -0.613064         -0.633593
# std            0.438694          0.500240          0.403657          0.413333
# min           -1.000000         -1.000000         -1.000000         -1.000000
# ...

# %%
HARD.select_dtypes(include='object')
# Out:
#                  Activity source
# 0                STANDING  train
# 1                STANDING  train
# 2                STANDING  train
# 3                STANDING  train
# 4                STANDING  train
# 5                STANDING  train
# 6                STANDING  train
# 7                STANDING  train
# 8                STANDING  train
# 9                STANDING  train
# 10               STANDING  train
# 11               STANDING  train
# 12               STANDING  train
# 13               STANDING  train
# 14               STANDING  train
# 15               STANDING  train
# 16               STANDING  train
# 17               STANDING  train
# 18               STANDING  train
# 19               STANDING  train
# 20               STANDING  train
# 21               STANDING  train
# 22               STANDING  train
# 23               STANDING  train
# 24               STANDING  train
# 25               STANDING  train
# 26               STANDING  train
# ...

# %%
label = HARD['Activity'].value_counts()

# %%
label.plot(kind='bar', colormap = 'Paired')

# %%
plt.figure(figsize=(9,5))
sns.countplot(HARD['Activity'], order = HARD['Activity'].value_counts().index)

# %%
# Duplicating datasets
hard_copy = HARD.copy()

# %%
source_data = hard_copy.pop('source')

# %%
hard_copy

# %%
# subject_data = hard_copy.pop('subject')
activity_data = hard_copy.pop('Activity')

# %%
hard_copy

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %%
scl = StandardScaler()

# %%
hard_copy
