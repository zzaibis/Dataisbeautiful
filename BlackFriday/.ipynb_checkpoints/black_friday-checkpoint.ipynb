# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
print(train.head())
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12,7))
sns.distplot(train['Purchase'], bins=25)
plt.xlabel('Purchases')
plt.ylabel('No of Buyers')
plt.title('Purchase amount Distribution')
plt.show()

# %%
train['source'] = 'train'
test['source'] = 'test'

# %%
black = pd.concat([train, test], ignore_index=True, sort=False)

# %%
print(black.isnull().sum())
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# source                             0
# dtype: int64

# %%
black['Product_Category_2'].fillna(0, inplace=True)
black['Product_Category_3'].fillna(0, inplace=True)

# %%
black.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3                 0
# Purchase                      233599
# source                             0
# dtype: int64

# %%
black['Gender'] = black['Gender'].map({
        'F': 0, 'M': 1
    })

# %%
black['Gender'].value_counts()
# Out:
# 1    590031
# 0    193636
# Name: Gender, dtype: int64

# %%
black.head()
# Out:
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042       0  0-17          10             A
# 1  1000001  P00248942       0  0-17          10             A
# 2  1000001  P00087842       0  0-17          10             A
# 3  1000001  P00085442       0  0-17          10             A
# 4  1000002  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase source
# 0                 0.0                 0.0    8370.0  train
# 1                 6.0                14.0   15200.0  train
# ...

# %%
black.Age.value_counts()
# Out:
# 26-35    313015
# 36-45    156724
# 18-25    141953
# 46-50     65278
# 51-55     54784
# 55+       30579
# 0-17      21334
# Name: Age, dtype: int64

# %%
black['Age'] = black['Age'].map({
        '0-17': 0,
        '18-25': 1,
        '26-35': 2,
        '36-45': 3,
        '46-50': 4,
        '51-55': 5,
        '55+' : 6
    })

# %%
black['City_Category'] = black['City_Category'].map({
        'A' : 0,
        'B' : 1,
        'C' : 2
    })

# %%
black['City_Category'].value_counts()
# Out:
# 1    329739
# 2    243684
# 0    210244
# Name: City_Category, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
black['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1     276425
# 2     145427
# 3     135428
# 4+    120671
# 0     105716
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
le = LabelEncoder()

# %%
black['Stay_In_Current_City_Years'] = le.fit_transform(black['Stay_In_Current_City_Years'])

# %%
black['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1    276425
# 2    145427
# 3    135428
# 4    120671
# 0    105716
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
black.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                          int64
# Age                             int64
# Occupation                      int64
# City_Category                   int64
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                      float64
# source                         object
# dtype: object

# %%
black.keys()
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase', 'source'],
#       dtype='object')

# %% [markdown]
# black["User_ID_Count"] = getCountVar(black, black, "User_ID")
# black["Age_Count"] =getCountVar(black, black, "Age")
# black["Occupation_Count"] =getCountVar(black, black, "Occupation")
# black["Product_Category_1_Count"] =getCountVar(black, black,"Product_Category_1")
# black["Product_Category_2_Count"] =getCountVar(black, black, "Product_Category_2")
# black["Product_Category_3_Count"] =getCountVar(black, black,"Product_Category_3")
# black["Product_ID_Count"] =getCountVar(black, black, "Product_ID")

# %%
# feature representing the count of each user
def getCountVar(compute_df, count_df, var_name):
    grouped_df = count_df.groupby(var_name)
    count_dict = {}
    for name, group in grouped_df:
        count_dict[name] = group.shape[0]
    count_list = []
    for index, row in compute_df.iterrows():
        name = row[var_name]
        count_list.append(count_dict.get(name, 0))
    return count_list

# %%
black.keys()
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase', 'source'],
#       dtype='object')

# %%
# %timeit

# %%
black["User_ID_Count"] = getCountVar(black, black, "User_ID")
black["Age_Count"] =getCountVar(black, black, "Age")
black["Occupation_Count"] =getCountVar(black, black, "Occupation")
black["Product_Category_1_Count"] =getCountVar(black, black,"Product_Category_1")
black["Product_Category_2_Count"] =getCountVar(black, black, "Product_Category_2")
black["Product_Category_3_Count"] =getCountVar(black, black,"Product_Category_3")
black["Product_ID_Count"] =getCountVar(black, black, "Product_ID")

# %%
black.keys()
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase', 'source',
#        'User_ID_Count', 'Age_Count', 'Occupation_Count',
#        'Product_Category_1_Count', 'Product_Category_2_Count',
#        'Product_Category_3_Count', 'Product_ID_Count'],
#       dtype='object')

# %%
#Divide into test and train:
train = black.loc[black['source']=='train']
test = black.loc[black['source']=='test']
#Drop unnecessary columns:
test.drop(['source'],axis=1,inplace=True)
train.drop(['source'],axis=1,inplace=True)
# Out:
# /home/excelsior/.local/lib/python3.6/site-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
#Export files as modified versions:
train.to_csv('train_modified.csv',index=False)
test.to_csv('test_modified.csv',index=False)
